# %%
random_dict = {
    "cheese" : 4,
    "spam" : 5,
    "eggs" : 7
}

# %%
id(random_dict)
# Out:
# 125067411967552

# %%
copy_dict = random_dictarr.copy()
id(copy_dict)
# Out:
# 125067130452160

# %%
copy_dict
# Out:
# {'cheese': 4, 'spam': 5, 'eggs': 7}

# %%
copy_dict["cheese"] = 23
copy_dict
# Out:
# {'cheese': 23, 'spam': 5, 'eggs': 7}

# %%
random_dict
# Out:
# {'cheese': 4, 'spam': 5, 'eggs': 7}
